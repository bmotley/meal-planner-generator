# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.hellofresh.com/recipes/vegetarian-recipes?page=50"
#grabs list of vegetarian recipes from hellofresh, 
#unfortunately not a complete list of vegetarian recipes, but a large number nonetheless.
page = requests.get(URL)
#saves url as page
soup = BeautifulSoup(page.content, "html.parser")
#saves page as BeautifulSoup object, parsing for html

# %%
title_elements = [title.get_text() for title in soup.find_all('h3')]
#looks for the title text of all h3 classes
titles_end = title_elements.index('NEWRecipes by Ingredient')
#creates an index for where the recipe titles end
titles = title_elements[:titles_end-0]
#creates list of cleaned recipe titles
# Out:
# ['Cheese Tortelloni',
#  'Buenos Días Black Bean Bowls',
#  'Heirloom Tomato Flatbreads',
#  'Creamy Santa Fe Gemelli Bake',
#  'Creamy Dreamy Mushroom Gemelli',
#  'Truffled Onion Grilled Cheeses',
#  'Trattoria Veggie Paninis',
#  'Brown Butter Gemelli',
#  'Roasted Veggie Caprese Bowls',
#  'Cheesy Mushroom Polenta',
#  'Veggie Burrito Bowls',
#  'Sesame Peanut Noodles',
#  'Chickpea-Powered Couscous',
#  'Charred Corn Elote Bowls',
#  'Garden Quesadillas',
#  'Truffled Mushroom Flatbreads',
#  'Tuscan Grilling Cheese',
#  'Guacamole Green Goddess Bowl',
#  'One-Pan Mushroom Ravioli Gratin',
#  'Cheesy Pesto Orzotto',
#  'Crispy Cheese and Veggie Fajitas',
#  'Smoky Black Bean and Corn Tostadas',
#  'Sweet Potato and Poblano Quesadillas',
#  'Sweet Potato Fajitas',
#  'Cremini and Zucchini Spaghetti',
#  'Green Pepper and Black Olive Flatbread',
#  'Veggie Burrito Bowls',
#  'Basil-Oil-Topped Parmesan Risotto',
#  'Asparagus Risotto',
#  'Roasted Broccoli and Potato Chowder',
#  'Cheesy Corn Tostadas',
#  'Harissa Sweet Potato Pita Pockets',
#  'Roasted Garlic Herb Penne',
#  'Butternut Squash and Sage Orechiette',
#  'Pear and Balsamic Onion Flatbreads',
#  'Cheesy Black Bean Enchiladas',
#  'Cheese-Crusted Quesadillas',
#  'Oven-Baked Parmesan Risotto',
#  'Creamiest Mushroom Ravioli',
#  'Curry-Spiced Cauliflower and Squash',
#  'Veggie Burrito Bowls',
#  'Veggie-licious Tacos',
#  'Easy-Peasy Ravioli Gratin',
#  "Lauren Conrad's Cauliflower Stir-Fry Bowls",
#  'Chipotle Taco Casserole',
#  'Seven Grain Chiles Rellenos',
#  'Crispy Chickpea Tacos',
#  'Pear and Balsamic Onion Flatbreads',
#  'Three-Cheese Tagliatelle Alfredo',
#  'Sweet Potato and Black Bean Tacos',
#  'Freekeh Feast Bowl',
#  'One-Pot Cheese Tortelloni',
#  'Harissa-Marinated Grilling Cheese',
#  'Paella Con Huevos',
#  'Patatas Bravas and Crispy Artichokes',
#  'Toasty Pesto Gnocchi',
#  'Pesto Flatbread (AKA Posh Pizza)',
#  'Mediterranean Grilling Cheese Bowls',
#  'Caramelized Shallot Risotto',
#  'Yellow Squash Flatbreads',
#  'Loaded Quinoa Bowls',
#  'Mediterranean Chickpea Orzo',
#  'Tomato Flatbreads',
#  "Za'atar-Crusted Goat Cheese",
#  'Veggie Chorizo Tacos',
#  'Sweet Potato Sunshine Bowl',
#  "Kickin' Goat Cheese Penne",
#  'Spinach Artichoke Pasta Bake',
#  'Penne Primavera',
#  'Vibrant Veggie Skewers',
#  'Smoky Stuffed Mushrooms',
#  'Mighty Meatless Bolognese',
#  "Chipotle Cheddar Mac 'N' Cheese",
#  'Tacos al Pastor',
#  'Butternut Squash Power Bowl',
#  "Za'atar-Roasted Root Veggies",
#  'Red Hot Tomato Soup',
#  'Baby Portobello and Orecchiette Primavera',
#  'Seitan Tacos El Diablo',
#  'Kimchi Hot Sauce Burritos',
#  'One-Pot Tortilla Soup',
#  'Gorgeous Greens Farro Bowl',
#  'Bell Pepper and Black Bean Quesadillas',
#  'Cumin Quinoa Bowl',
#  'Creamy Lemon Tagliatelle',
#  'Freekeh Power Bowl',
#  'Creamiest Mushroom Ravioli',
#  'Peppy Pepper Fajitas',
#  'Maple and Brown Butter Gnocchi',
#  'Black Bean Burgers',
#  'Brown Rice Bibimbap',
#  'Seitan and Black Bean Chili',
#  "Spiced Cauliflower Mac 'N' Cheese",
#  'Crispy Cauliflower and Squash Tacos',
#  'Mediterranean Whole-Roasted Cauliflower',
#  'Roasted Cauliflower Flatbreads',
#  'Caramelized Shallot Risotto',
#  'Creepy Crawly Tagliatelle Pasta',
#  'Queso Frito Rice',
#  "Shepherd's Pie, Veggie Style",
#  'Oven-Roasted Mediterranean Cauliflower',
#  'No-Brainer Grain Salad',
#  'Seitan Tacos al Pastor',
#  'Mushroom Lo Mein',
#  'Buttered-Up Butternut Squash Risotto',
#  'Yellow Squash Flatbreads',
#  "Za'atar-Crusted Grilling Cheese",
#  'One-Pot Tortelloni',
#  'Eggplant Parm Sandwiches',
#  'Sweet Potato Steaks',
#  'Early Summer Potato Salad',
#  'Quick Creamy Penne',
#  'PLT (Portobello, Lettuce & Tomato)',
#  'Cozy Chickpea and Egg Skillet',
#  'Summer Succotash Stuffed Peppers',
#  'Beany Zucchini Quesadillas',
#  'Charred Avocado Orecchiette',
#  'Sriracha Sesame Wonton Pasta',
#  'Grilling Cheese Burgers',
#  'Sweet Potato Sunshine Salad',
#  'Summer Quinoa Salad',
#  'Eggplant and Sun-Dried Tomato Linguine',
#  'Get Your Greens Rice Bowl',
#  'Chunky Funky Veggie Burgers',
#  'Gorgeous Greens Farro Bowl',
#  'Mushroom Lo Mein',
#  'Southwestern Tortellini Salad',
#  'Smoky Seitan Rice Bowl',
#  'Rock the Zucchini Boat',
#  'Veggie Fattoush Salad',
#  'Creamy Mushroom Ragu',
#  'Feisty Frijole Tostadas',
#  'Nectarine and Zucchini Panzanella',
#  'Southwestern Black Bean Cakes',
#  'Pillowy Parmesan Raviolini',
#  'Freekeh and Lentil Jumble',
#  'Vibrant Veggie Skewers',
#  'Mega Mushroom Burgers',
#  'Cannellini Bean Panzanella',
#  'Seitan Tacos Al Pastor',
#  'Powerhouse Eggplant Polenta',
#  'Persian-Spiced Cauliflower Quinoa Bowl',
#  'Baby Portobello and Orecchiette Primavera',
#  'Toasted Brown Rice Bowl',
#  'Mediterranean Tomato and Asparagus Bake',
#  'Crunchy Veggie and Lentil Salad',
#  'Sweet Potato Chickpea Curry',
#  'Greek Salad Flatbreads',
#  'Mighty Meatless Bolognese',
#  'Pesto Tortelloni Bake',
#  'Risotto alla Tex-Mex',
#  'Eggplant and Sun-Dried Tomato Linguine',
#  'Ultimate Spring Salad',
#  'Pad See Ew',
#  'Sweet Potato Sunshine Salad',
#  'Kale Chip Quinoa Bowl',
#  'Golden Grain-Stuffed Peppers',
#  'Spring Greens Gnocchi',
#  'Warming Cauliflower and Lentil Dal',
#  'Eggs-In-A-Hole Skillet',
#  'Silky Oven-Roasted Eggplant',
#  'Peppy Pepper Fajitas',
#  'Bok Choy and Black Rice Veggie Bowl',
#  'Tortelloni En Brodo',
#  'Gorgeous Green Farro Bowl',
#  'One-Pot Tortilla Soup',
#  'Flatbread Fattoush Salad',
#  'Southwestern Superfood Jumble',
#  'Mighty Meatless Bolognese',
#  'Wholesome Hoisin Veggie Stir-Fry',
#  'Brown Rice Bibimbap',
#  'Sicilian Farro Caponata',
#  'Utterly Up-Beet Salad',
#  'Creamy Dreamy Linguine',
#  'Colorful Confetti Salad',
#  'Tunisian Freekeh Stew',
#  'Jammy Fig and Brie Grilled Cheese',
#  'Roasted Cauliflower',
#  'Game Day Black Bean Chili',
#  'Rapid Butternut Squash Agnolotti',
#  'Kale and Quinoa Power-Up Salad',
#  'Yellow Squash Flatbreads',
#  'Sweet Potato and Black Bean Tacos',
#  'Tuscan Ribollita',
#  'Oven-Roasted Cauliflower',
#  'Greek Eggplant Ragu',
#  'Chipotle Seitan Chili',
#  'Cumin-Roasted Carrot and Avocado Salad',
#  'Winter Veggies and Brown Rice',
#  'Freekeh Soup',
#  'Zucchini Flatbreads',
#  "Spiced Cauliflower Mac 'N' Cheese",
#  'Ultra-Creamy Risotto',
#  'Melty Gruyere-Topped Quinoa',
#  "Shepherd's Pie, Veggie Style",
#  'Roasted Cauliflower and Squash Tacos',
#  'Bountiful Barley Bowl',
#  'Pesto Flatbread (aka Posh Pizza)',
#  'Protein-Packed Rice Bowl',
#  'Pillowy Gnocchi',
#  'Tri-Color Quinoa Salad',
#  'Tortellini en Brodo',
#  'Crispy Chickpea Bowl',
#  'Indian-Inspired Eggplant',
#  'Stuffed Squash Boats',
#  'One-Pot Tortellini Wonder',
#  'Red Rice Bowl',
#  'Polenta Pancakes',
#  'Feel-Good Freekeh Salad',
#  'Harvest Flatbread',
#  'Marble Potato and Brussels Sprout Hash',
#  'Hoisin Stir-Fry',
#  'Swiss Chard and Wild Mushroom Penne',
#  'Fattoush Salad',
#  'Spicy Shakshuka',
#  'Crispy Sunchoke and Quinoa Salad',
#  'Crispy Chickpea and Roasted Cauliflower Salad',
#  'One-Pan Ravioli Gratin',
#  'Cheesy Polenta Cakes',
#  'Roasted Cauliflower',
#  'Deconstructed Ratatouille',
#  'Portobello Burgers and Sweet Potato Fries',
#  'Fig and Quinoa Salad',
#  'Greek Flatbread',
#  'Parmesan Raviolini',
#  'Smoky Black Bean Cakes',
#  'Zucchini and Asparagus Farro Bowl',
#  'Veggie Lo Mein',
#  'Portobello and Orecchiette Primavera',
#  'Italian Panzanella',
#  'One-Pot Mexican Quinoa',
#  'Seitan Sloppy Joes',
#  'Israeli Couscous Bowl',
#  'Wild Mushroom Ravioli',
#  'Charred Scallion and Corn Flatbread',
#  'Toasted Brown Rice Bowl',
#  'Nectarine and Zucchini Panzanella',
#  'Black Bean and Charred Bell Pepper Quesadillas',
#  'Eggplant and Sun-dried Tomato Linguine',
#  'Vegetarian Burrito Bowl',
#  'Peach & Nectarine Orzo Salad',
#  'Caramelized Veggie Skewers',
#  'Zesty Corn & Red Bean Salad',
#  'Peach and Mozzarella Flatbread',
#  'Stuffed Zucchini Boats',
#  'Zucchini & Smoky Bean Quesadillas',
#  'Vegetarian Paella',
#  'Pan-Seared Gnocchi',
#  'Portobello Burgers',
#  'Skillet Chilaquiles']

# %%
text_elements2 = [link.get('href') for link in soup.find_all('a')]
#gets all the links from the web page under the 'a' class
target_ibdex1 = text_elements2.index('/recipes/ingredients')
#creates index for end of link list
target_ibdex2 = text_elements2.index('/recipes/casserole-recipes')
#creates index for beginning of link list
links = text_elements2[target_ibdex2+1:target_ibdex1-0]
#creates clean list of links that correspond to title list

for i in range( len(links)):
    links[i] = "https://www.hellofresh.com" + links[i]
#adds the full url so it's a clickable link
# Out:
# ['https://www.hellofresh.com/recipes/cheese-tortelloni-in-a-mushroom-sauce-5d893112c6d5102c1923bdc5',
#  'https://www.hellofresh.com/recipes/buenos-dias-black-bean-bowls-5d892f9862ccf0134a593bdc',
#  'https://www.hellofresh.com/recipes/heirloom-tomato-flatbreads-5d76b7670dcef1001723e9ea',
#  'https://www.hellofresh.com/recipes/creamy-santa-fe-gemelli-bake-5d76b6b60dcef1000f5d1a8e',
#  'https://www.hellofresh.com/recipes/creamy-dreamy-mushroom-gemelli-5d6e74aad611f800157039a2',
#  'https://www.hellofresh.com/recipes/truffled-onion-grilled-cheeses-5d6e74817d730d000f0c8e87',
#  'https://www.hellofresh.com/recipes/trattoria-veggie-paninis-5d56f3cd0b44ec000c4a81b2',
#  'https://www.hellofresh.com/recipes/brown-butter-asparagus-gemelli-5d485f2c9697b100155ba6e6',
#  'https://www.hellofresh.com/recipes/roasted-veggie-caprese-bowl-5d3ef0a4e203d200135e68cd',
#  'https://www.hellofresh.com/recipes/cheesy-mushroom-polenta-5d35ed3aa641a50017622355',
#  'https://www.hellofresh.com/recipes/veggie-burrito-bowls-5d35cbc8769619000a461944',
#  'https://www.hellofresh.com/recipes/sesame-peanut-noodles-5d14d52f7ae20d000a65bebc',
#  'https://www.hellofresh.com/recipes/chickpea-powered-mediterranean-couscous-5d128e0cf67e6800147d8c5b',
#  'https://www.hellofresh.com/recipes/charred-corn-elote-bowls-5d0aae5b190767000b4dc888',
#  'https://www.hellofresh.com/recipes/garden-quesadillas-5cf80a0b4e84a7000e178fb8',
#  'https://www.hellofresh.com/recipes/be-pearl-barley-salad-577d5c453933dce36c8b4568',
#  'https://www.hellofresh.com/recipes/mushroom-ravioli-pasta-salad-57728d61d545254d1d8b4567',
#  'https://www.hellofresh.com/recipes/charred-scallion-and-corn-flatbread-5772895577d68d361f8b4567',
#  'https://www.hellofresh.com/recipes/toasted-brown-rice-bowl-57728904d804b53c128b4568',
#  'https://www.hellofresh.com/recipes/nectarine-and-zucchini-panzanella-5768114cf8b25e81168b4567',
#  'https://www.hellofresh.com/recipes/black-bean-quesadillas-57680f494dab712c458b4567',
#  'https://www.hellofresh.com/recipes/roasted-eggplant-linguine-575eb89ffd2cb9914c8b4567',
#  'https://www.hellofresh.com/recipes/veggie-burrito-bowl-575eb822fd2cb9ea498b4568',
#  'https://www.hellofresh.com/recipes/peach-and-nectarine-orzo-salad-575591cdf8b25ebe4c8b4569',
#  'https://www.hellofresh.com/recipes/caramelized-veggie-skewers-5755906df8b25ecc478b4567',
#  'https://www.hellofresh.com/recipes/au-cuban-confetti-salad-574d9970fd2cb96d6f8b4567',
#  'https://www.hellofresh.com/recipes/peach-and-arugula-flatbread-574d98bcfd2cb9906b8b4567',
#  'https://www.hellofresh.com/recipes/stuffed-summer-squash-boats-574d9815f8b25e9a448b4568',
#  'https://www.hellofresh.com/recipes/charred-zucchini-and-bean-quesadilla-5743288afd2cb9543b8b4567',
#  'https://www.hellofresh.com/recipes/uk-record-breaking-vegetarian-paella-5743281afd2cb9aa3a8b4567',
#  'https://www.hellofresh.com/recipes/uk-pan-fried-gnocchi-574327b0f8b25ef35f8b4567',
#  'https://www.hellofresh.com/recipes/balsamic-portobello-burger-5739e67cf8b25ecc468b4567',
#  'https://www.hellofresh.com/recipes/skillet-chilaquiles-5739e5ce4dab71cc7b8b4567']

# %%
from pandas import pandas as pd
#importing pandas to create dataframes
recipe_df = pd.DataFrame(list(zip(titles, links)),
               columns =['Name', 'Link'])
#creates dataframe with the recipe title and link to recipe
recipe_df
# Out:
#                                   Name  \
# 0                    Cheese Tortelloni
# 1         Buenos Días Black Bean Bowls
# 2           Heirloom Tomato Flatbreads
# 3         Creamy Santa Fe Gemelli Bake
# 4       Creamy Dreamy Mushroom Gemelli
# ..                                 ...
# 245  Zucchini & Smoky Bean Quesadillas
# 246                  Vegetarian Paella
# 247                 Pan-Seared Gnocchi
# 248                 Portobello Burgers
# 249                Skillet Chilaquiles
#
#                                                   Link
# 0    https://www.hellofresh.com/recipes/cheese-tort...
# 1    https://www.hellofresh.com/recipes/buenos-dias...
# 2    https://www.hellofresh.com/recipes/heirloom-to...
# 3    https://www.hellofresh.com/recipes/creamy-sant...
# 4    https://www.hellofresh.com/recipes/creamy-drea...
# ..                                                 ...
# 245  https://www.hellofresh.com/recipes/charred-zuc...
# 246  https://www.hellofresh.com/recipes/uk-record-b...
# 247  https://www.hellofresh.com/recipes/uk-pan-frie...
# 248  https://www.hellofresh.com/recipes/balsamic-po...
# 249  https://www.hellofresh.com/recipes/skillet-chi...
#
# [250 rows x 2 columns]

# %%
random_recipes = recipe_df.sample(n=2)
#creates a sub-dataframe from the recipe dataframe above, selecting two recipes at random.
#change n number to increase or decrease random recipe amounts. 
#(will have to add to the below code to compensate for changes)

# %%
#First Recipe
recipe_URL = random_recipes.iloc[0]['Link']
#pulls string of first link
recipe_page = requests.get(recipe_URL)
#grabs the web page for first recipe
recipe_soup = BeautifulSoup(recipe_page.content, "html.parser")
#creates a soup object for easier html parsing

#Second Recipe
recipe_URL2 = random_recipes.iloc[1]['Link']
#pulls string of second link
recipe_page2 = requests.get(recipe_URL2)
#grabs the web page for second recipe
recipe_soup2 = BeautifulSoup(recipe_page2.content, "html.parser")
#creates a soup object for easier html parsing

# %%
whitelist = [
  'p'
]
#Creates a whitelist of only 'p' html classes, which is where the recipe elements are.
recipe_elements = [t for t in recipe_soup.find_all(text=True) if t.parent.name in whitelist]
#Finds all text objects from 'p' html classes
target_ibdex = recipe_elements.index('Salt')
#Final recipe item index

recipe_parts = recipe_elements[1:target_ibdex-0]
#gets all the ingredients from the recipe starting from the second object to the created index
recipe = [' '.join(recipe_parts[i:i+2]) for i in range(0, len(recipe_parts), 2)]
#creates a list to join amounts and ingredient labels for easy viewing


recipe_elements2 = [t for t in recipe_soup2.find_all(text=True) if t.parent.name in whitelist]
#Finds all text objects from 'p' html classes
target_ibdex3 = recipe_elements2.index('Salt')
#Final recipe item index
recipe_parts2 = recipe_elements2[1:target_ibdex3-0]
#gets all the ingredients from the recipe starting from the second object to the created index
recipe2 = [' '.join(recipe_parts2[i:i+2]) for i in range(0, len(recipe_parts2), 2)]
#creates a list to join amounts and ingredient labels for easy viewing


grocerylist_df = pd.DataFrame({"ingredient":recipe + recipe2})
#creates dataframe of both recipe ingredients

# %%
grocerylist_df_clean = grocerylist_df[grocerylist_df["ingredient"].str.contains("unit")==False]
#cleans dataframe of non-ingredients

# %%
print(random_recipes.iloc[0,0])
#prints first recipe title
print(random_recipes.iloc[1,0])
#prints second recipe title
print(grocerylist_df_clean)
#prints clean grocery list
print(random_recipes.iloc[0,1])
#prints first recipe link (clickable)
print(random_recipes.iloc[1,1])
#prints second recipe link (clickable)
# Out:
# Cheesy Mushroom Polenta
# Creamy Santa Fe Gemelli Bake
#                             ingredient
# 0               4 ounce Grape Tomatoes
# 2             8 ounce Button Mushrooms
# 3                       2 clove Garlic
# 5       1 tablespoon Italian Seasoning
# 7          Â½ cup Italian Cheese Blend
# 8                      Â½ cup Cornmeal
# 9                 4 teaspoon Olive Oil
# 10                 4 tablespoon Butter
# 14  1 tablespoon Southwest Spice Blend
# 15                  1 tablespoon Flour
# 16             14 ounce Diced Tomatoes
# 17               6 ounce Gemelli Pasta
# 18            Â½ cup Panko Breadcrumbs
# 19         Â½ cup Mexican Cheese Blend
# 20         Â¼ cup Monterey Jack Cheese
# 21           4 tablespoon Cream Cheese
# 22                1 teaspoon Hot Sauce
# https://www.hellofresh.com/recipes/cheesy-mushroom-polenta-5d35ed3aa641a50017622355
# https://www.hellofresh.com/recipes/creamy-santa-fe-gemelli-bake-5d76b6b60dcef1000f5d1a8e
